# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
#colors
bacnco_color = '#023047'
bancco_color = '#219ebc'
bancoc_color = '#ffb703'
bcanco_color = '#c44900'
conabc_color = '#c9aef1'
nabcco_color = '#ff00bf'
nabcoc_color = '#005c99'
nacobc_color = '#993399'

bacnco_color_light = '#8098a3'
bancco_color_light = '#90cede'
bancoc_color_light = '#ffdb81'
bcanco_color_light = '#e2a480'
conabc_color_light = '#c9aef1'
nabcco_color_light = '#ff80df'
nabcoc_color_light = '#80aecc'
nacobc_color_light = '#cc99cc'
# import matplotlib.colors as mcolors
# def lighten_color(hex_color, amount=0.5):
#     # Convert hex color to RGB
#     rgb = mcolors.hex2color(hex_color)
#     # Lighten the color by blending with white
#     light_rgb = [(1 - amount) * c + amount for c in rgb]
#     # Convert back to hex
#     light_hex = mcolors.to_hex(light_rgb)
#     return light_hex

# # Original color
# original_color = "#023047"
# # Lightened color
# lightened_color = lighten_color(original_color, amount=0.5)  # You can adjust the amount for more or less pale

# print("Original color:", original_color)
# print("Lightened color:", lightened_color)

# %% [markdown]
# # All unfiltered inner joins

# %%
bacnco = [10.277, 62.04 , 127.71, 633.4, 1270.7, 6403,  12787]
bancco = [10.572, 63.24, 124.94 , 640.5, 1295.6 , 6699, 12891]
bancoc = [10.828, 65.22, 129.46 , 663.0, 1327.6, 6739, 13106]
bcanco = [8.994 , 57.94, 117.97, 590.7, 1191.4 , 5833, 11592]
conabc = [7.215 , 43.63 , 89.36, 410.8, 918.6, 4607,  9020]
nabcco = [9.167, 58.92, 117.45 , 584.6, 1151.4, 5716, 11397]
nabcoc = [9.612, 60.38 , 121.00, 618.3, 1252.5, 5929, 11943]
nacobc = [8.437, 52.06, 105.05, 544.1 , 1208.4 , 5463,  11014]


x = [1000, 5000, 10000, 50000, 100000, 500000, 1000000]


# Create a plot
plt.figure()
plt.plot(x, bacnco, marker='o', linestyle='', color=bacnco_color, label='{B,A,C,N,Co}')
plt.plot(x, bancco, marker='o', linestyle='', color=bancco_color, label='{B,A,N,C,Co}')
plt.plot(x, bancoc, marker='o', linestyle='', color=bancoc_color, label='{B,A,N,Co,C}')
plt.plot(x, bcanco, marker='o', linestyle='', color=bcanco_color, label='{B,C,A,N,Co}')
plt.plot(x, conabc, marker='o', linestyle='', color=conabc_color, label='{Co,N,A,B,C}')
plt.plot(x, nabcco, marker='o', linestyle='', color=nabcco_color, label='{N,A,B,C,Co}')
plt.plot(x, nabcoc, marker='o', linestyle='', color=nabcoc_color, label='{N,A,B,Co,C}')
plt.plot(x, nacobc, marker='o', linestyle='', color=nacobc_color, label='{N,A,Co,B,C}')

plt.xscale('log')
plt.yscale('log')

# Add titles and labels
# plt.title('Execution time of different join orders')
plt.ylabel('Time (in ms)', fontsize=12)
plt.xlabel('Number of tuples', fontsize=12)
plt.legend(fontsize=12)

# Save the plot as an SVG file
plt.savefig('join_order_all_inner.svg', format='svg', bbox_inches='tight')
plt.savefig('join_order_all_inner.pdf', format='pdf', bbox_inches='tight')

# Display the plot (optional)
plt.show()

# %%
bacnco_est = [6590.4,32955.2,65763.20000000001,330003.2,660496,3299132.8,6603020.800000001]
bancco_est = [6795.2,33977.6,67881.6,340001.6,680248,3399566.4,6801510.4]
bancoc_est = [7000,35000,70000,350000,700000,3500000,7000000]
bcanco_est = [6308.8,31549.4,62850.40000000001,316255.4,633337,3161036.6,6330097.600000001]
conabc_est = [3999.6,19919.6,39819.6,199019.6,398019.6,1990019.6,3980019.6]
nabcco_est = [5383.6,26886,53690,269010,538256.4,2689574.8,5381518.8]
nabcoc_est = [5588.4,27908.4,55808.4,279008.4,558008.4,2790008.4,5580008.4]
nacobc_est = [5108.4,25508.4,51008.4,255008.4,510008.4,2550008.4,5100008.4]

bacnco_order = [' NLIJ NLJ NLJ NLJ',' NLIJ NLJ NLJ NLJ',' NLIJ NLJ NLJ NLJ',' NLIJ NLJ NLJ NLJ',' NLIJ NLJ NLJ NLJ',' NLIJ NLJ NLJ NLJ',' NLIJ NLJ NLJ NLJ']
bancco_order = [' NLIJ NLJ NLJ NLJ',' NLIJ NLJ NLJ NLJ',' NLIJ NLJ NLJ NLJ',' NLIJ NLJ NLJ NLJ',' NLIJ NLJ NLJ NLJ',' NLIJ NLJ NLJ NLJ',' NLIJ NLJ NLJ NLJ']
bancoc_order = [' NLIJ NLJ NLJ NLJ',' NLIJ NLJ NLJ NLJ',' NLIJ NLJ NLJ NLJ',' NLIJ NLJ NLJ NLJ',' NLIJ NLJ NLJ NLJ',' NLIJ NLJ NLJ NLJ',' NLIJ NLJ NLJ NLJ']
bcanco_order = [' NLJ NLIJ NLJ NLJ',' NLJ NLIJ NLJ NLJ',' NLJ NLIJ NLJ NLJ',' NLJ NLIJ NLJ NLJ',' NLJ NLIJ NLJ NLJ',' NLJ NLIJ NLJ NLJ',' NLJ NLIJ NLJ NLJ']
conabc_order = [' NLJ HJ NLIJ NLJ',' NLJ HJ NLIJ NLJ',' NLJ HJ NLIJ NLJ',' NLJ HJ NLIJ NLJ',' NLJ HJ NLIJ NLJ',' NLJ HJ NLIJ NLJ',' NLJ HJ NLIJ NLJ']
nabcco_order = [' HJ NLIJ NLJ NLJ',' HJ NLIJ NLJ NLJ',' HJ NLIJ NLJ NLJ',' HJ NLIJ NLJ NLJ',' HJ NLIJ NLJ NLJ',' HJ NLIJ NLJ NLJ',' HJ NLIJ NLJ NLJ']
nabcoc_order = [' HJ NLIJ NLJ NLJ',' HJ NLIJ NLJ NLJ',' HJ NLIJ NLJ NLJ',' HJ NLIJ NLJ NLJ',' HJ NLIJ NLJ NLJ',' HJ NLIJ NLJ NLJ',' HJ NLIJ NLJ NLJ']
nacobc_order = [' HJ NLJ NLIJ NLJ',' HJ NLJ NLIJ NLJ',' HJ NLJ NLIJ NLJ',' HJ NLJ NLIJ NLJ',' HJ NLJ NLIJ NLJ',' HJ NLJ NLIJ NLJ',' HJ NLJ NLIJ NLJ']

# %%
plt.figure()
plt.plot(x, bacnco_est, marker='o', linestyle='', color=bacnco_color, label='{B,A,C,N,Co}')
plt.plot(x, bancco_est, marker='o', linestyle='', color=bancco_color, label='{B,A,N,C,Co}')
plt.plot(x, bancoc_est, marker='o', linestyle='', color=bancoc_color, label='{B,A,N,Co,C}')
plt.plot(x, bcanco_est, marker='o', linestyle='', color=bcanco_color, label='{B,C,A,N,Co}')
plt.plot(x, conabc_est, marker='o', linestyle='', color=conabc_color, label='{Co,N,A,B,C}')
plt.plot(x, nabcco_est, marker='o', linestyle='', color=nabcco_color, label='{N,A,B,C,Co}')
plt.plot(x, nabcoc_est, marker='o', linestyle='', color=nabcoc_color, label='{N,A,B,Co,C}')
plt.plot(x, nacobc_est, marker='o', linestyle='', color=nacobc_color, label='{N,A,Co,B,C}')

plt.xscale('log')
plt.yscale('log')
plt.xticks(fontsize = 12)
plt.yticks(fontsize = 12)

# Add titles and labels
plt.title('Estimations of different join orders')
# plt.ylabel('Time (in ms)')
plt.xlabel('Number of tuples', fontsize = 12)
plt.legend(fontsize = 12)

# Save the plot as an SVG file
plt.savefig('join_order_all_inner_est.svg', format='svg', bbox_inches='tight')
plt.savefig('join_order_all_inner_est.pdf', format='pdf', bbox_inches='tight')

# Display the plot (optional)
plt.show()

# %%
bacnco_est_comp = [x / best for x, best in zip(bacnco_est,conabc_est) ]
bancco_est_comp = [x / best for x, best in zip(bancco_est,conabc_est) ]
bancoc_est_comp = [x / best for x, best in zip(bancoc_est,conabc_est) ]
bcanco_est_comp = [x / best for x, best in zip(bcanco_est,conabc_est) ]
conabc_est_comp = [x / best for x, best in zip(conabc_est,conabc_est) ]
nabcco_est_comp = [x / best for x, best in zip(nabcco_est,conabc_est) ]
nabcoc_est_comp = [x / best for x, best in zip(nabcoc_est,conabc_est) ]
nacobc_est_comp = [x / best for x, best in zip(nacobc_est,conabc_est) ]

bacnco_act_comp = [x / best for x, best in zip(bacnco,conabc) ]
bancco_act_comp = [x / best for x, best in zip(bancco,conabc) ]
bancoc_act_comp = [x / best for x, best in zip(bancoc,conabc) ]
bcanco_act_comp = [x / best for x, best in zip(bcanco,conabc) ]
conabc_act_comp = [x / best for x, best in zip(conabc,conabc) ]
nabcco_act_comp = [x / best for x, best in zip(nabcco,conabc) ]
nabcoc_act_comp = [x / best for x, best in zip(nabcoc,conabc) ]
nacobc_act_comp = [x / best for x, best in zip(nacobc,conabc) ]

bacnco_est_comp = [bacnco_act_comp[4], bacnco_act_comp[6]]
bancco_est_comp = [bancco_est_comp[4], bancco_est_comp[6]]
bancoc_est_comp = [bancoc_est_comp[4], bancoc_est_comp[6]]
bcanco_est_comp = [bcanco_est_comp[4], bcanco_est_comp[6]]
conabc_est_comp = [conabc_est_comp[4], conabc_est_comp[6]]
nabcco_est_comp = [nabcco_est_comp[4], nabcco_est_comp[6]]
nabcoc_est_comp = [nabcoc_est_comp[4], nabcoc_est_comp[6]]
nacobc_est_comp = [nacobc_est_comp[4], nacobc_est_comp[6]]

bacnco_act_comp = [bacnco_act_comp[4], bacnco_act_comp[6]]
bancco_act_comp = [bancco_act_comp[4], bancco_act_comp[6]]
bancoc_act_comp = [bancoc_act_comp[4], bancoc_act_comp[6]]
bcanco_act_comp = [bcanco_act_comp[4], bcanco_act_comp[6]]
conabc_act_comp = [conabc_act_comp[4], conabc_act_comp[6]]
nabcco_act_comp = [nabcco_act_comp[4], nabcco_act_comp[6]]
nabcoc_act_comp = [nabcoc_act_comp[4], nabcoc_act_comp[6]]
nacobc_act_comp = [nacobc_act_comp[4], nacobc_act_comp[6]]


bacnco_est_comp = [(x - 1) * 100 for x in bacnco_est_comp]
bancco_est_comp = [(x - 1) * 100 for x in bancco_est_comp]
bancoc_est_comp = [(x - 1) * 100 for x in bancoc_est_comp]
bcanco_est_comp = [(x - 1) * 100 for x in bcanco_est_comp]
conabc_est_comp = [(x - 1) * 100 for x in conabc_est_comp]
nabcco_est_comp = [(x - 1) * 100 for x in nabcco_est_comp]
nabcoc_est_comp = [(x - 1) * 100 for x in nabcoc_est_comp]
nacobc_est_comp = [(x - 1) * 100 for x in nacobc_est_comp]

bacnco_act_comp = [(x - 1) * 100 for x in bacnco_act_comp]
bancco_act_comp = [(x - 1) * 100 for x in bancco_act_comp]
bancoc_act_comp = [(x - 1) * 100 for x in bancoc_act_comp]
bcanco_act_comp = [(x - 1) * 100 for x in bcanco_act_comp]
conabc_act_comp = [(x - 1) * 100 for x in conabc_act_comp]
nabcco_act_comp = [(x - 1) * 100 for x in nabcco_act_comp]
nabcoc_act_comp = [(x - 1) * 100 for x in nabcoc_act_comp]
nacobc_act_comp = [(x - 1) * 100 for x in nacobc_act_comp]

categories = [10000, 100000]

# Number of bars per category
bar_width = 0.06
index = np.arange(len(categories))

# Create a grouped bar chart
plt.figure()
plt.figure(figsize=(8, 4.5))
plt.bar(index, bacnco_est_comp, bar_width, label='{B,A,C,N,Co} Estimation', hatch='/',edgecolor='black', color=bacnco_color_light)
plt.bar(index + bar_width, bacnco_act_comp, bar_width, label='{B,A,C,N,Co}',edgecolor='black', color=bacnco_color)
plt.bar(index + bar_width + bar_width, bancco_est_comp, bar_width, label='{B,A,N,C,Co} Estimation',hatch='/',edgecolor='black', color=bancco_color_light)
plt.bar(index + bar_width + bar_width + bar_width, bancco_act_comp, bar_width, label='{B,A,N,C,Co}',edgecolor='black', color=bancco_color)
plt.bar(index + bar_width + bar_width + bar_width + bar_width, bancoc_est_comp, bar_width, label='{B,A,N,Co,C} Estimation',hatch='/',edgecolor='black', color=bancoc_color_light)
plt.bar(index + bar_width + bar_width + bar_width + bar_width + bar_width, bancoc_act_comp, bar_width, label='{B,A,N,Co,C}',edgecolor='black', color=bancoc_color)

# plt.xlabel('Joins')
# # plt.ylabel('Factor of t')
# plt.xticks(index + bar_width + 0.3, categories)
# plt.xticks(rotation=45)
# # plt.legend()
# plt.legend(loc='upper left', bbox_to_anchor=(1, 1))

# # Adjusting the layout to make room for the legend
# plt.tight_layout()
# plt.show()

i = 6;
plt.bar(index + bar_width * i, bcanco_est_comp, bar_width, hatch='/', edgecolor='black', label='{B,C,A,N,Co} Estimation', color=bcanco_color_light)
i = i + 1;
plt.bar(index + bar_width * i, bcanco_act_comp, bar_width, label='{B,C,A,N,Co}', edgecolor='black', color=bcanco_color)
i = i + 1;
# plt.bar(index + bar_width * i, conabc_est_comp, bar_width,edgecolor='black',hatch='/', label='{Co,N,A,B,C} Estimation', color=conabc_color)
# i = i + 1;
# plt.bar(index + bar_width * i, conabc_act_comp, bar_width,edgecolor='black', label='{Co,N,A,B,C}', color=conabc_color)
# i = i + 1;
plt.bar(index + bar_width * i, nabcco_est_comp, bar_width,edgecolor='black',hatch='/', label='{N,A,B,C,CO} Estimation', color=nabcco_color_light)
i = i + 1;
plt.bar(index + bar_width * i, nabcco_act_comp, bar_width,edgecolor='black', label='{N,A,B,C,CO}', color=nabcco_color)
i = i + 1;
plt.bar(index + bar_width * i, nabcoc_est_comp, bar_width,edgecolor='black',hatch='/', label='{N,A,B,Co,C} Estimation', color=nabcoc_color_light)
i = i + 1;
plt.bar(index + bar_width * i, nabcoc_act_comp, bar_width,edgecolor='black', label='{N,A,B,Co,C}', color=nabcoc_color)
i = i + 1;
plt.bar(index + bar_width * i, nacobc_est_comp, bar_width,edgecolor='black',hatch='/', label='{N,A,Co,B,C} Estimation', color=nacobc_color_light)
i = i + 1;
plt.bar(index + bar_width * i, nacobc_act_comp, bar_width,edgecolor='black', label='{N,A,Co,B,C}', color=nacobc_color)
# plt.gca().yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
# plt.ylim(300000, None)

# plt.yscale('log')
# Add titles and labels
# plt.title('Percentage by which the join orders are slower than the optimal one ')
plt.xlabel('Dataset', fontsize = 12)
plt.ylabel('Percent', fontsize = 12)
plt.xticks(index + bar_width + 0.33, categories)
plt.xticks(fontsize = 12)
# plt.legend()
plt.legend(loc='upper left', bbox_to_anchor=(1, 1), fontsize = 12)

# Adjusting the layout to make room for the legend
plt.tight_layout()


# Display the plot
plt.savefig('join_order_comp.svg', format='svg', bbox_inches='tight')
plt.savefig('join_order_comp.pdf', format='pdf', bbox_inches='tight')

plt.show()

# %%
bacnco_order = [' NLIJ NLJ NLJ NLJ',' NLIJ NLJ NLJ NLJ',' NLIJ NLJ NLJ NLJ',' NLIJ NLJ NLJ NLJ',' NLIJ NLJ NLJ NLJ',' NLIJ NLJ NLJ NLJ',' NLIJ NLJ NLJ NLJ']
bancco_order = [' NLIJ NLJ NLJ NLJ',' NLIJ NLJ NLJ NLJ',' NLIJ NLJ NLJ NLJ',' NLIJ NLJ NLJ NLJ',' NLIJ NLJ NLJ NLJ',' NLIJ NLJ NLJ NLJ',' NLIJ NLJ NLJ NLJ']
bancoc_order = [' NLIJ NLJ NLJ NLJ',' NLIJ NLJ NLJ NLJ',' NLIJ NLJ NLJ NLJ',' NLIJ NLJ NLJ NLJ',' NLIJ NLJ NLJ NLJ',' NLIJ NLJ NLJ NLJ',' NLIJ NLJ NLJ NLJ']
bcanco_order = [' NLJ NLIJ NLJ NLJ',' NLJ NLIJ NLJ NLJ',' NLJ NLIJ NLJ NLJ',' NLJ NLIJ NLJ NLJ',' NLJ NLIJ NLJ NLJ',' NLJ NLIJ NLJ NLJ',' NLJ NLIJ NLJ NLJ']
conabc_order = [' NLJ HJ NLIJ NLJ',' NLJ HJ NLIJ NLJ',' NLJ HJ NLIJ NLJ',' NLJ HJ NLIJ NLJ',' NLJ HJ NLIJ NLJ',' NLJ HJ NLIJ NLJ',' NLJ HJ NLIJ NLJ']
nabcco_order = [' HJ NLIJ NLJ NLJ',' HJ NLIJ NLJ NLJ',' HJ NLIJ NLJ NLJ',' HJ NLIJ NLJ NLJ',' HJ NLIJ NLJ NLJ',' HJ NLIJ NLJ NLJ',' HJ NLIJ NLJ NLJ']
nabcoc_order = [' HJ NLIJ NLJ NLJ',' HJ NLIJ NLJ NLJ',' HJ NLIJ NLJ NLJ',' HJ NLIJ NLJ NLJ',' HJ NLIJ NLJ NLJ',' HJ NLIJ NLJ NLJ',' HJ NLIJ NLJ NLJ']
nacobc_order = [' HJ NLJ NLIJ NLJ',' HJ NLJ NLIJ NLJ',' HJ NLJ NLIJ NLJ',' HJ NLJ NLIJ NLJ',' HJ NLJ NLIJ NLJ',' HJ NLJ NLIJ NLJ',' HJ NLJ NLIJ NLJ']

# %%
(1 - 0.1237) * 100000 * 7 * (1 / 7)
# Out:
# 87630.0
